# %%
import pandas as pd
from tqdm import tqdm
import missingno as msgno

from matplotlib.ticker import FuncFormatter
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

# %%
data = pd.read_csv('../data/01-nypd-complaints-clean.csv').drop('Unnamed: 0', axis=1)
data.date_start = pd.to_datetime(data.date_start)
data.date_reported = pd.to_datetime(data.date_reported)
data.head()
# Out:
# /Users/nastja/.pyenv/versions/py39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       cmp_id date_start time_start    date_end  time_end  loc_precinct  \
# 0  394506329 2019-12-31   17:30:00         NaN       NaN          32.0
# 1  968873685 2019-12-29   16:31:00  12/29/2019  16:54:00          47.0
# 2  509837549 2019-12-15   18:45:00         NaN       NaN         109.0
# 3  352454313 2019-12-28   01:00:00         NaN       NaN          47.0
# 4  248803469 2008-09-05   21:41:00         NaN       NaN           NaN
#
#   date_reported  key_code                     offense_desc  \
# 0    2019-12-31       118                DANGEROUS WEAPONS
# 1    2019-12-29       113                          FORGERY
# 2    2019-12-29       578                    HARRASSMENT 2
# 3    2019-12-28       126          MISCELLANEOUS PENAL LAW
# 4    2008-09-05       101  MURDER & NON-NEGL. MANSLAUGHTER
#
#                     internal_desc  ... jurisdiction_desc park_name  \
# 0            WEAPONS POSSESSION 3  ...  N.Y. POLICE DEPT       NaN
# 1  FORGERY,ETC.,UNCLASSIFIED-FELO  ...  N.Y. POLICE DEPT       NaN
# 2           HARASSMENT,SUBD 3,4,5  ...  N.Y. POLICE DEPT       NaN
# 3         RECKLESS ENDANGERMENT 1  ...  N.Y. POLICE DEPT       NaN
# 4                             NaN  ...  N.Y. POLICE DEPT       NaN
#
#   susp_age_group susp_race susp_sex transit_district  \
# 0        UNKNOWN       NaN      NaN              NaN
# 1        UNKNOWN       NaN      NaN              NaN
# 2          25-44   UNKNOWN        M              NaN
# 3          18-24     BLACK        M              NaN
# 4        UNKNOWN       NaN      NaN              NaN
#
#          loc_borough_patrol vic_age_group        vic_race vic_sex
# 0     PATROL BORO MAN NORTH       UNKNOWN         UNKNOWN       E
# 1         PATROL BORO BRONX       UNKNOWN         UNKNOWN       E
# 2  PATROL BORO QUEENS NORTH         25-44  WHITE HISPANIC       F
# 3         PATROL BORO BRONX       UNKNOWN         UNKNOWN       E
# 4                       NaN         25-44           BLACK       M
#
# [5 rows x 25 columns]

# %%
SEX_OFFENSES = ['SEX CRIMES', 'RAPE']
data_sex = data.query('offense_desc in @SEX_OFFENSES')

data_sex.offense_desc = data_sex.offense_desc.apply(lambda of: 'SEX CRIMES' if of == 'RAPE' else of)
data_sex.internal_desc = data_sex.internal_desc\
    .apply(lambda of:'RAPE' if of.startswith('RAPE') else of)

# map subcategories into a bigger group
SEX_OFFENSE_CATEGORY_MAP = {
    'SEXUAL ABUSE 3,2': 'Sex Abuse',
    'CHILD, ENDANGERING WELFARE': 'Child Endangerment',
    'SEXUAL MISCONDUCT,INTERCOURSE': 'Sex Misconduct',
    'SEXUAL MISCONDUCT,DEVIATE': 'Sex Misconduct',
    'OBSCENITY, PERFORMANCE 3': 'Obscenity',
    'OBSCENITY, MATERIAL 3': 'Obscenity',
    'SEXUAL ABUSE': 'Sex Abuse',
    'RAPE': 'Rape'
    }

data_sex.internal_desc = data_sex.internal_desc.map(SEX_OFFENSE_CATEGORY_MAP)
data_sex.dropna(subset=['internal_desc'], inplace=True)

data_sex.internal_desc.value_counts(dropna=False)
# Out:
# /Users/nastja/.pyenv/versions/py39/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /Users/nastja/.pyenv/versions/py39/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Sex Abuse             42774
# Child Endangerment    22335
# Rape                  21648
# Sex Misconduct         4974
# Obscenity               128
# Name: internal_desc, dtype: int64

# %% [markdown]
# **Sexual misconduct** is not usually not referring to specific criminal behavior or even a civil violation, like sex abuse. It can cover everything from asking a work subordinate out on a date to pressuring them for sex in exchange for career advancement.
#
# **Sex abuse**, also referred to as molestation, is abusive sexual behavior by one person upon another. It is often perpetrated using force or by taking advantage of another. When force is immediate, of short duration, or infrequent, it is called **sexual assault**. The term also covers any behavior by an adult or older adolescent towards a child to stimulate any of the involved sexually.
#
# To sum up:
# * Sex misconduct does not necessarily involves physical force. It can be any unwanted sexual advances.
# * Sex abuse implies a use of force (physical, blackmail, threats, ...)
# * Rape implies unwanted penetration
# * Child Endangerment involves sexual advances towards children

# %%
data_sex.vic_race = data_sex.vic_race.str.lower().str.capitalize()
RACE_MAP = {race: race for race in data_sex.vic_race.unique()}
RACE_MAP['Asian / pacific islander'] = 'Asian'
RACE_MAP['American indian/alaskan native'] = 'Native American'
RACE_MAP['Other'] = 'Unknown'
data_sex.vic_race = data_sex.vic_race.map(RACE_MAP)

# %%
data_sex['vic_group'] = data_sex.apply(lambda row: f'{row.vic_race}_{row.vic_sex}_{row.vic_age_group}', axis=1)
data_sex['vic_group'].value_counts().head(5)
# Out:
# /var/folders/8w/pj7s5vq54kb7tqh8qpy_pxsc0000gn/T/ipykernel_13504/3928168883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sex['vic_group'] = data_sex.apply(lambda row: f'{row.vic_race}_{row.vic_sex}_{row.vic_age_group}', axis=1)
# Black_F_<18               12635
# White hispanic_F_<18      11859
# White_F_25-44              6032
# Black_F_25-44              5778
# White hispanic_F_25-44     5091
# Name: vic_group, dtype: int64

# %%
# women of color, underage is the biggest victim group
(data_sex['vic_group'].value_counts() / data_sex.shape[0]).iloc[:2].sum()*100
# Out:
# 26.664779716739783

# %%
# trend
yearly = data_sex.groupby([data_sex.date_start.dt.year]).count().fillna(0).cmp_id.loc[2006:]

plt.figure(figsize=(16,6))
((yearly-yearly.shift(1))/yearly * 100).plot.bar(color='grey')
plt.title('Trend: Rate of change', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Trend: Rate of change')

# %%
fig = plt.figure(figsize=(10,8), dpi=150)
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0.05, hspace=0.27)
ax0 = fig.add_subplot(gs[0, 0])


background_color = "#fafafa"
fig.patch.set_facecolor(background_color) 
ax0.set_facecolor(background_color)

# Plots 
# Happiest
data = ((yearly-yearly.shift(1))/yearly * 100)


color_map = ['#e7e9e7' for _ in range(20)]
color_map[14] =  high_c

#base
ax0.bar(data.index, data, 
       edgecolor='darkgray',color='lightgray',alpha=0.1)
# actual
ax0.bar(data.index, data, 
       edgecolor='darkgray',color=color_map)

ax0.axes.get_xaxis().set_ticks([])
ax0.axes.get_yaxis().set_ticks([])


for s in ['top','left', 'bottom', 'right']:
    ax0.spines[s].set_visible(False)
    
for i in range(0,3):
    ax0.annotate(list(data.index)[i], 
                   xy=(i, -0.1), 
                   va = 'top', ha='center',fontweight='light',fontsize=8, color='white',rotation=90)


plt.show()
plt.savefig('../')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8w/pj7s5vq54kb7tqh8qpy_pxsc0000gn/T/ipykernel_13504/4242449074.py in <module>
#      11 # Plots
#      12 # Happiest
# ---> 13 data = ((yearly-yearly.shift(1))/yearly * 100)
#      14
#      15
#
# NameError: name 'yearly' is not defined

# %% [markdown]
# # Stand-Out Facts
#
# * most common victim group (age, race, sex): Black & Hispanic underage women account for 27% of victims
# * time to report: 60% are reported within a day, 81% within a month, 92% within a year. Only 6% are reported over a year late
# * weekly offenses in NYC: 7639 in 2020
# * accounts for 1% of all offenses

# %%
# num weekly offenses in 2020
mean_weekly_offenses_2020 = data.groupby([data.date_start.dt.year, data.date_start.dt.week]).count().fillna(0).groupby(level=0).mean()\
    .astype(int).cmp_id.loc[2020]
print(f'On average, there were {mean_weekly_offenses_2020} offenses recorded per week in 2020.')

pct_offenses = round(data_sex.shape[0] / data.shape[0] * 100)
top_sex_offense = data_sex.value_counts().index.loc[0]
print(f'Sex offenses account for just about {pct_offenses}% of all offenses. Largest group is {data_sex["vic_group"].value_counts().index.loc[0]}')

pct_reported_within_day = round(((data_sex.date_reported - data_sex.date_start).dt.days.value_counts() / data_sex.shape[0]).iloc[:2].sum()*100,2)
print(f'{pct_reported_within_day} cases are reported within a day of the incident')
# Out:
# /var/folders/8w/pj7s5vq54kb7tqh8qpy_pxsc0000gn/T/ipykernel_9594/2644941021.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   mean_weekly_offenses_2020 = data.groupby([data.date_start.dt.year, data.date_start.dt.week]).count().fillna(0).groupby(level=0).mean()\
# On average, there were 7639 offenses recorded per week in 2020.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/8w/pj7s5vq54kb7tqh8qpy_pxsc0000gn/T/ipykernel_9594/2644941021.py in <module>
#       5
#       6 pct_offenses = round(data_sex.shape[0] / data.shape[0] * 100)
# ----> 7 top_sex_offense = data_sex.value_counts().index.loc[0]
#       8 print(f'Sex offenses account for just about {pct_offenses}% of all offenses. Largest group is {data_sex["vic_group"].value_counts().index.loc[0]}')
#       9
#
# AttributeError: 'MultiIndex' object has no attribute 'loc'

# %%
# colours
low_c = '#DD24B6'
high_c = '#008794'
plt.rcParams["font.family"] = "monospace"

# %%
# inspiration ; https://www.kaggle.com/gaetanlopez/how-to-make-clean-visualizations
# changed code signif.

fig = plt.figure(figsize=(5,3),dpi=150)
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0.2, hspace=0.4)
ax0 = fig.add_subplot(gs[0, 0])

background_color = "#fafafa"
fig.patch.set_facecolor(background_color) # figure background color
ax0.set_facecolor(background_color) 

ax0.text(1.13,0.85,"Sex Offenses in NYC, 2006-2020",color='#323232',fontsize=23, fontweight='bold', fontfamily='sanserif',ha='center', va='center')
ax0.text(1.13,-0.35,"stand-out facts",color='lightgray',fontsize=23, fontweight='bold', fontfamily='monospace',ha='center')

ax0.text(0.43,0.4,"1%",color=high_c,fontsize=20, fontweight='bold', fontfamily='monospace',ha='center')
ax0.text(0.43,0.1,"Of All Offenses",color='gray',fontsize=10, fontfamily='monospace',ha='center')

ax0.text(0.93,0.4,"24%",color=high_c,fontsize=20, fontweight='bold', fontfamily='monospace',ha='center')
ax0.text(0.93,0.1,"Down\nsince 2006",color='gray',fontsize=10, fontfamily='monospace',ha='center', va='center')

ax0.text(1.33,0.4,"40%",color=low_c,fontsize=20, fontweight='bold', fontfamily='monospace',ha='center')
ax0.text(1.33,0.1,"Reported\nlate",color='gray',fontsize=10, fontfamily='monospace',ha='center', va='center')

ax0.text(1.83,0.4,"Underage\nBlack Women",color=low_c,fontsize=17, fontweight='bold', fontfamily='monospace',ha='center', va='center')
ax0.text(1.83,0.1,"Most at Risk",color='gray',fontsize=10, fontfamily='monospace',ha='center')

ax0.set_yticklabels('')
ax0.set_xticklabels('')
ax0.tick_params(axis='both',length=0)

for s in ['top','right','left','bottom']:
    ax0.spines[s].set_visible(False)
    
import matplotlib.lines as lines
l1 = lines.Line2D([0.15, 1.95], [0.67, 0.67], transform=fig.transFigure, figure=fig,color = 'gray', linestyle='-',linewidth = 1.1, alpha = .5)
fig.lines.extend([l1])
l2 = lines.Line2D([0.15, 1.95], [0.07, 0.07], transform=fig.transFigure, figure=fig,color = 'gray', linestyle='-',linewidth = 1.1, alpha = .5)
fig.lines.extend([l2])
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8w/pj7s5vq54kb7tqh8qpy_pxsc0000gn/T/ipykernel_13504/3658678183.py in <module>
#       2 # changed code signif.
#       3
# ----> 4 fig = plt.figure(figsize=(5,3),dpi=150)
#       5 gs = fig.add_gridspec(1, 1)
#       6 gs.update(wspace=0.2, hspace=0.4)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# * sex offenses amount to just 1% of all offenses, a remarkably small percentage.

# %%
yearly_offense = data.groupby([data.date_start.dt.year, data.offense_desc]).count().fillna(0).cmp_id.loc[2006:,:].unstack()
yearly_offense
# Out:
# offense_desc  ABORTION  ADMINISTRATIVE CODE  ADMINISTRATIVE CODES  \
# date_start
# 2006               NaN               1148.0                   2.0
# 2007               2.0               1099.0                   2.0
# 2008               NaN               1146.0                   4.0
# 2009               NaN               1239.0                   NaN
# 2010               NaN               1132.0                   2.0
# 2011               NaN               1154.0                   1.0
# 2012               NaN               1149.0                   4.0
# 2013               1.0               1125.0                   1.0
# 2014               NaN               1104.0                   NaN
# 2015               2.0               1063.0                   2.0
# 2016               NaN               1009.0                   1.0
# 2017               1.0                890.0                   NaN
# 2018               1.0               1024.0                   NaN
# 2019               NaN               1095.0                   NaN
# 2020               NaN                895.0                   NaN
#
# offense_desc  ALCOHOLIC BEVERAGE CONTROL LAW  ANTICIPATORY OFFENSES   ARSON  \
# date_start
# 2006                                    73.0                   15.0  1691.0
# 2007                                    77.0                   13.0  1562.0
# 2008                                    58.0                   14.0  1842.0
# 2009                                    71.0                   11.0  1438.0
# 2010                                    86.0                   10.0  1457.0
# 2011                                    79.0                    9.0  1248.0
# 2012                                    92.0                    8.0  1254.0
# 2013                                    64.0                    8.0  1183.0
# 2014                                    69.0                    5.0  1185.0
# 2015                                    78.0                    2.0  1037.0
# 2016                                    96.0                    2.0   772.0
# 2017                                   148.0                    5.0   702.0
# 2018                                   101.0                    6.0   725.0
# 2019                                   115.0                    9.0   695.0
# 2020                                    70.0                   11.0   809.0
#
# offense_desc  ASSAULT 3 & RELATED OFFENSES  BURGLAR'S TOOLS  BURGLARY  \
# date_start
# 2006                               51515.0            148.0   22941.0
# 2007                               51046.0            192.0   21642.0
# 2008                               50238.0            171.0   20716.0
# 2009                               50163.0            218.0   19437.0
# 2010                               52669.0            222.0   18707.0
# 2011                               50865.0            273.0   18863.0
# 2012                               54501.0            292.0   19312.0
# 2013                               53547.0            288.0   17423.0
# 2014                               53787.0            373.0   16841.0
# 2015                               52246.0            286.0   15153.0
# 2016                               52381.0            263.0   13026.0
# 2017                               51493.0            259.0   12120.0
# 2018                               53185.0            325.0   11680.0
# 2019                               52768.0            307.0   10727.0
# 2020                               43313.0            229.0   15378.0
#
# offense_desc  CRIMINAL MISCHIEF & RELATED OF  ...  \
# date_start                                    ...
# 2006                                 52985.0  ...
# 2007                                 55828.0  ...
# 2008                                 56275.0  ...
# 2009                                 52169.0  ...
# 2010                                 50975.0  ...
# 2011                                 49249.0  ...
# 2012                                 47793.0  ...
# 2013                                 43900.0  ...
# 2014                                 47634.0  ...
# 2015                                 48492.0  ...
# 2016                                 48743.0  ...
# 2017                                 49314.0  ...
# 2018                                 47199.0  ...
# 2019                                 46845.0  ...
# 2020                                 46679.0  ...
#
# offense_desc  POSSESSION OF STOLEN PROPERTY  PROSTITUTION & RELATED OFFENSES  \
# date_start
# 2006                                 3029.0                             45.0
# 2007                                 2926.0                            103.0
# 2008                                 2816.0                             89.0
# 2009                                 2840.0                             71.0
# 2010                                 3101.0                             87.0
# 2011                                 3657.0                             80.0
# 2012                                 3384.0                             78.0
# 2013                                 3003.0                             62.0
# 2014                                 2516.0                            126.0
# 2015                                 2029.0                            113.0
# 2016                                 1678.0                            130.0
# 2017                                 1967.0                             61.0
# 2018                                 1765.0                             85.0
# 2019                                 1403.0                             57.0
# 2020                                 1152.0                            206.0
#
# offense_desc    RAPE  ROBBERY  SEX CRIMES  THEFT-FRAUD  \
# date_start
# 2006          1524.0  22855.0      4771.0       5815.0
# 2007          1289.0  21401.0      4453.0       6099.0
# 2008          1291.0  22379.0      4340.0       6689.0
# 2009          1216.0  18594.0      4520.0       5085.0
# 2010          1419.0  19598.0      4454.0       5127.0
# 2011          1444.0  19778.0      4631.0       5631.0
# 2012          1441.0  20173.0      4393.0       6155.0
# 2013          1392.0  19127.0      3974.0       5026.0
# 2014          1323.0  16574.0      4229.0       4702.0
# 2015          1422.0  16956.0      4577.0       5000.0
# 2016          1405.0  15517.0      4931.0       4514.0
# 2017          1432.0  13990.0      5290.0       4322.0
# 2018          1525.0  12920.0      5620.0       3980.0
# 2019          1477.0  13342.0      5444.0       3577.0
# 2020          1035.0  13080.0      3649.0       2042.0
#
# offense_desc  UNAUTHORIZED USE OF A VEHICLE  UNDER THE INFLUENCE OF DRUGS  \
# date_start
# 2006                                 1284.0                           NaN
# 2007                                 1303.0                           NaN
# 2008                                 1185.0                           NaN
# 2009                                 1171.0                           1.0
# 2010                                 1312.0                           NaN
# 2011                                 1312.0                           NaN
# 2012                                 1411.0                           NaN
# 2013                                 1532.0                           NaN
# 2014                                 1709.0                           1.0
# 2015                                 1653.0                           1.0
# 2016                                 1799.0                           NaN
# 2017                                 1661.0                           NaN
# 2018                                 1621.0                           NaN
# 2019                                 1596.0                           NaN
# 2020                                 1398.0                           NaN
#
# offense_desc  UNLAWFUL POSS. WEAP. ON SCHOOL  VEHICLE AND TRAFFIC LAWS
# date_start
# 2006                                     6.0                    5822.0
# 2007                                     3.0                    5508.0
# 2008                                     5.0                    5237.0
# 2009                                     9.0                    6162.0
# 2010                                     5.0                    6625.0
# 2011                                     8.0                    5823.0
# 2012                                     5.0                    5570.0
# 2013                                    10.0                    6088.0
# 2014                                     5.0                    5839.0
# 2015                                     2.0                    6282.0
# 2016                                     3.0                    6580.0
# 2017                                     2.0                    6451.0
# 2018                                     2.0                    6725.0
# 2019                                     3.0                    6751.0
# 2020                                     2.0                    6304.0
#
# [15 rows x 64 columns]

# %%
source = (yearly_offense['RAPE'] + yearly_offense['SEX CRIMES'])
sns.scatterplot(y=source, x=source/yearly_offense.sum(1) * 100, alpha=0.5, color='grey')
plt.title('Percentage of sex offense over the years')

# add average
# add 2020
# Out:
# Text(0.5, 1.0, 'Percentage of sex offense over the years')

# %% [markdown]
# # Q1: Did the sexual violence go down in the last 10 years?
# ## Did the rate of offenses committed at home go up during the pandemic?

# %% [markdown]
# # Q2: Who suffers from sex offenses the most?

# %% [markdown]
# # Q3: Where sexual violence usually occurs (home/street/office)?

# %% [markdown]
# # Q4: With sexual offense commited on the streets, what are the hotspots in NYC?

# %% [markdown]
# # Q5: Are people more willing to report sexual offenses since Me Too movement started?
